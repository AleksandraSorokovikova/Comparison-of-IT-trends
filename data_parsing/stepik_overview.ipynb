# %%
import pandas as pd
from parsers.parse import parse_scrapy
from parsers.stepikSpider import stepikSpider

# %%
pages = ['https://stepik.org/course/{0}'.format(i) for i in range(66779, 104844)]
stepik_data = []
parse_scrapy(stepikSpider, pages, stepik_data)
# Out:
# 100%|██████████| 38065/38065 [35:27<00:00, 17.90it/s]

# %%
df = pd.DataFrame(stepik_data)
df
# Out:
#           time                                           name  \
# 0     20200320  Как добиться успеха, решая задачки на Степике
# 1     20200320                                 Нанотехнологии
# 2     20200320       Educational System in the United Kingdom
# 3     20200320         The Country Studies of the UK(6 Grade)
# 4     20200320                           Литература (5 класс)
# ..         ...                                            ...
# 534   20211004                   Управление личными финансами
# 535   20211008            Технология создания убеждающей речи
# 536   20211013                                   Композитинг
# 537   20211025                  Менеджмент в сельском туризме
# 538   20211027                            Финансовая политика
#
#                                            description participants    price
# 0     очередная реинкарнация легендарного милого се...       6,808         0
# ...
