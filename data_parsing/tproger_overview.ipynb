# %%
import pandas as pd
from parsers.parse import parse_scrapy
from parsers.tprogerSpider import tprogerSpider

# %%
links_file = open("links.txt", 'r')
pages = links_file.readlines()
links_file.close()
troger_data = []
parse_scrapy(tprogerSpider, pages, troger_data)
# Out:
# 100%|██████████| 2985/2985 [00:57<00:00, 51.92it/s]

# %%
import pandas as pd
df = pd.DataFrame(troger_data)
df
# Out:
#                            time  \
# 0     2021-11-07T13:13:54+03:00
# 1     2021-11-03T14:39:24+03:00
# 2     2021-11-01T13:54:57+03:00
# 3     2021-11-11T13:10:01+03:00
# 4     2021-11-10T19:09:24+03:00
# ...                         ...
# 2980  2014-12-13T00:20:42+03:00
# 2981  2013-12-01T23:55:57+04:00
# 2982  2013-03-08T16:24:40+04:00
# 2983  2014-12-05T12:11:51+03:00
# 2984  2014-02-11T11:07:22+04:00
#
#                                                    tags  views comments saved
# 0                  [Интернет, Карьера, Работа, Сервисы]   5080        2    10
# 1         [Алгоритмы, Математика и теория вероятностей]   1779        0     4
# 2                                   [Пост пользователя]    380        0     0
# 3                                [Партнёрский материал]   1222        0     5
# 4     [JavaScript, Алгоритмы, Для начинающих, Пост п...    562        0     2
# ...                                                 ...    ...      ...   ...
# ...
